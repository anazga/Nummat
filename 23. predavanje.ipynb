# %% [markdown]
# # Numerička matematika - 23. predavanje

# %% [markdown]
# ## 1. Gradijentni spust

# %% [markdown]
# U sljedećem predavanju detaljnije objašnjavamo metodu najbržeg silaska i njezina poboljšanja

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("MOOs4-omCoU")
display(vid)

# %% [markdown]
# U strojnom učenju najviše se koristi stohastički gradijentni spust. Više o metodi najbržeg silaska možete pronaći ovdje (sljedeći linkovi  NISU gradivo koje se ispituje na ispitu iz Numeričke matematike ). [link1](http://fa.bianp.net/teaching/2018/COMP-652/)
# Također, opsežan je i rad koji objašnjava različite varijante (ADAM, ADAGARD i slično)(https://arxiv.org/pdf/1609.04747.pdf)

# %% [markdown]
# ## 2. Metode linijskog pretraživanja

# %% [markdown]
# U sljedećem videu objašnjeno je kako, nakon što smo odredili smjer pada funkcije određujemo koliko ćemo se u tom smjeru pomaknuti, prilikom računanja nove iteracije.

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("4d3ncceoYMU")
display(vid)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/4d3ncceoYMU"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
